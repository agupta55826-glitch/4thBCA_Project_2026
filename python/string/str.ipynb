# %%
s1="abcd"
s2="efgh"

print(s1<s2)
# Out:
# True

# %%
whiloop='akash'
i=0
while i<len(whiloop):
    print(whiloop[i])
    i+=1
# Out:
# a
# k
# a
# s
# h

# %%
s="python"

for i in s:
    print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
# Literal in Python
#list
list=['akash',234,'python',True,False,'simran','satendra']
# list.append(20)#not support add function
# list.remove(234)
# list.reverse()
# list.clear()

# del list

# sort accessing order
# list.sort()
# list.pop(0)
# list.pop(5)
list.insert(6,34)
print(list)
# Out:
# ['akash', 234, 'python', True, False, 'simran', 34, 'satendra']

# %%
t=('python','akash',12)
# t.append('ankit')#not changes anything
# t.sort()
print(t)
# Out:
# ('python', 'akash', 12)

# %%
num=[153,26,'python','akash']
# num.reverse()
num.sort()

print(num)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 3
#       1 num=[153,26,'python','akash']
#       2 # num.reverse()
# ----> 3 num.sort()
#       4
#       5 print(num)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
# solution of number and sring sorting 
my_list1=[3,'akash',5,'vikash',True,False]
my_list1=list1(map(str1, my_list1))
my_list1.sort()
print(my_list1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 3
#       1 # solution of number and sring sorting
#       2 my_list1=[3,'akash',5,'vikash',True,False]
# ----> 3 my_list1=list1(map(str1, my_list1))
#       4 my_list1.sort()
#       5 print(my_list1)
#
# NameError: name 'list1' is not defined

# %%
# second method solution of number and sring sorting
my_list=[3,'akash',5,'vikash',True,False]
my_list.sort(key=lambda x: str(x))
print(my_list)
# Out:
# [3, 5, False, True, 'akash', 'vikash']

# %%
list=['akash','vikash','nikhil','amit']
# print(list)
# list[3]
# list.insert(4,'aniket')
# list.sort()
# print(list)
# list.pop(3)
# list.insert(1,29)

# print(list.index('nikhil'))
# list.index('akash')
# Out:
# 0

# %%
# slicing
h=[5,6,48,12,94,26,31,89,21,49]
# p=h[2:6:1]
# print(p)
# h[::6]
# h[3:]
# print(h)


# defference bbetween two values

# h[2:8:2]

# from back side print values

# h[-1::-1]

# h[:-1]
h[-1:]
# Out:
# [49]

# %%
x='abhishek'
# print(x[0])
x[1:5:1]
# Out:
# 'bhis'

# %%
# touple
t1=(1,2,3,4,5)
t2=list(t1)
print(t2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 # touple
#       2 t1=(1,2,3,4,5)
# ----> 3 t2=list(t1)
#       4 print(t2)
#
# TypeError: 'list' object is not callable
